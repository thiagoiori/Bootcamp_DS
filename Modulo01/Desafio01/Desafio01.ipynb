# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagoiori/Bootcamp_DS/blob/main/Modulo01/Desafio01/Desafio01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

pd.options.display.float_format = "{:.2f}".format

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/thiagoiori/Bootcamp_DS/main/Modulo01/Desafio01/A124524189_28_143_208.csv", 
                    sep=";", 
                    encoding="ISO-8859-1", 
                    skiprows=3, 
                    skipfooter=12, 
                    engine="python", 
                    decimal=",")

# %%
ax = dados.sort_values(by="2008/Ago", ascending=False).plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(12,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor por unidade da federação")
plt.show()

# %% [markdown]
# # Desafio 1: Escolher um título mais descritivo
# # Desafio 2: Selecionar o mês mais recente - Março/2021

# %%
ax = dados.sort_values(by="2021/Mar", ascending=False).plot(x="Unidade da Federação", y="2021/Mar", kind="bar", figsize=(12,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Gasto de procedimentos hospitalares por unidade federativa em Março/2021")
plt.show()
